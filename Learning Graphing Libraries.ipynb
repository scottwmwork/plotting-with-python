# %%
#imports

# plotting libraries
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns


# other
import pandas as pd
import numpy as np

# %%
df_LongLat = pd.read_csv('CitiesLongitudeLatitude.csv')

# %%
len(df_LongLat.City)
# Out:
# 28925

# %%
# Goal 1: Plot all cities on map of USA
# Goal 2: make different plots of data


# Goal 1: Plot all cities on map of USA
df = df_LongLat[df_LongLat['Longitude'] < 50] # drop row
sns.scatterplot(x="Longitude", y="Latitude", data=df)

# %%
# Goal 2: make different plots of data
gilbert = collection.find_one({'City': 'Gilbert AZ'})
mesa = collection.find_one({'City': 'Mesa AZ'})
tempe = collection.find_one({'City': 'Tempe AZ'})
phoenix = collection.find_one({'City':'Phoenix AZ'})
chandler = collection.find_one({'City': 'Chandler AZ'})

# %%
# create data
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
 
# use the scatter function
plt.scatter(x, y, s=z*1000, alpha=0.5)
plt.show()
